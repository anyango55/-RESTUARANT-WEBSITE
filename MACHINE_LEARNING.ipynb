# %% [markdown]
# <a href="https://colab.research.google.com/github/anyango55/-RESTUARANT-WEBSITE/blob/master/MACHINE_LEARNING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas
# !wget https://raw.githubusercontent.com/MicrosoftDocs/mslearn-introduction-to-machine-learning/main/graphing.py
# !wget https://raw.githubusercontent.com/MicrosoftDocs/mslearn-introduction-to-machine-learning/main/Data/doggy-boot-harness.csv
# !pip install statsmodels

 
data = {
    'boot_size' : [ 39, 38, 37, 39, 38, 35, 37, 36, 35, 40, 
                    40, 36, 38, 39, 42, 42, 36, 36, 35, 41, 
                    42, 38, 37, 35, 40, 36, 35, 39, 41, 37, 
                    35, 41, 39, 41, 42, 42, 36, 37, 37, 39,
                    42, 35, 36, 41, 41, 41, 39, 39, 35, 39
 ],
    'harness_size': [ 58, 58, 52, 58, 57, 52, 55, 53, 49, 54,
                59, 56, 53, 58, 57, 58, 56, 51, 50, 59,
                59, 59, 55, 50, 55, 52, 53, 54, 61, 56,
                55, 60, 57, 56, 61, 58, 53, 57, 57, 55,
                60, 51, 52, 56, 55, 57, 58, 57, 51, 59
                ]
}

dataset = pandas.DataFrame(data)

dataset
# Out:
# --2022-07-10 11:22:46--  https://raw.githubusercontent.com/MicrosoftDocs/mslearn-introduction-to-machine-learning/main/graphing.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21511 (21K) [text/plain]
# Saving to: ‘graphing.py.2’
#
# graphing.py.2       100%[===================>]  21.01K  --.-KB/s    in 0.001s
#
# 2022-07-10 11:22:46 (30.6 MB/s) - ‘graphing.py.2’ saved [21511/21511]
#
# --2022-07-10 11:22:46--  https://raw.githubusercontent.com/MicrosoftDocs/mslearn-introduction-to-machine-learning/main/Data/doggy-boot-harness.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# ...

# %%
import statsmodels.formula.api as smf

formula = "bootsize ~ harness_size"

model = smf.ols(formula = formula, data = dataset)

if not hasattr(model, 'params'):
    print("Model selected but it does not have parameters set. We need to train it!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/patsy/compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35     try:
# ---> 36         return f(*args, **kwargs)
#      37     except Exception as e:
#
# /usr/local/lib/python3.7/dist-packages/patsy/eval.py in eval(self, expr, source_name, inner_namespace)
#     165         return eval(code, {}, VarLookupDict([inner_namespace]
# --> 166                                             + self._namespaces))
#     167
#
# <string> in <module>()
#
# NameError: name 'bootsize' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# <ipython-input-5-a64189edc8ea> in <module>()
#       3 formula = "bootsize ~ harness_size"
#       4
# ...

# %%
import pandas
# !wget https://raw.githubusercontent.com/MicrosoftDocs/mslearn-introduction-to-machine-learning/main/graphing.py
# !wget https://raw.githubusercontent.com/MicrosoftDocs/mslearn-introduction-to-machine-learning/main/Data/doggy-boot-harness.csv

dataset = pandas.read_csv('doggy-boot-harness.csv')

dataset.head()
# Out:
# --2022-07-15 11:06:10--  https://raw.githubusercontent.com/MicrosoftDocs/mslearn-introduction-to-machine-learning/main/graphing.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21511 (21K) [text/plain]
# Saving to: ‘graphing.py’
#
# graphing.py         100%[===================>]  21.01K  --.-KB/s    in 0s
#
# 2022-07-15 11:06:10 (84.4 MB/s) - ‘graphing.py’ saved [21511/21511]
#
# --2022-07-15 11:06:10--  https://raw.githubusercontent.com/MicrosoftDocs/mslearn-introduction-to-machine-learning/main/Data/doggy-boot-harness.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# ...

# %%
#FILTERNING DATA

#1Look at harness size
print('harness sizes')
print(dataset.harness_size)

#delete sex and age in years column
 
del dataset ["sex"]
del dataset ["age_years"]

#print available data after updates

print("Updated data")
print(dataset.columns.values)
# Out:
# harness sizes
# 0     58
# 1     58
# 2     52
# 3     58
# 4     57
# 5     52
# 6     55
# 7     53
# 8     49
# 9     54
# 10    59
# 11    56
# 12    53
# 13    58
# 14    57
# 15    58
# 16    56
# 17    51
# 18    50
# 19    59
# 20    59
# 21    59
# 22    55
# 23    50
# 24    55
# 25    52
# 26    53
# 27    54
# 28    61
# 29    56
# 30    55
# 31    60
# 32    57
# 33    56
# 34    61
# 35    58
# 36    53
# 37    57
# 38    57
# 39    55
# 40    60
# 41    51
# 42    52
# 43    56
# 44    55
# 45    57
# 46    58
# 47    57
# 48    51
# 49    59
# Name: harness_size, dtype: int64
# Updated data
# ['boot_size' 'harness_size']

# %%
#FILTERING BY ROWS
#Print top rows

print(dataset.head())

print(dataset.tail())
# Out:
#    boot_size  harness_size
# 0         39            58
# 1         38            58
# 2         37            52
# 3         39            58
# 4         38            57
#     boot_size  harness_size
# 45         41            57
# 46         39            58
# 47         39            57
# 48         35            51
# 49         39            59

# %%
print(f"We have {len(dataset)} rows of data")

is_small = dataset.harness_size < 55
print("\nWhether the dogs harness size id smaller than 55:")
print(is_small)
# Out:
# We have 50 rows of data
#
# Whether the dogs harness size id smaller than 55:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5      True
# 6     False
# 7      True
# 8      True
# 9      True
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17     True
# 18     True
# 19    False
# 20    False
# 21    False
# 22    False
# 23     True
# 24    False
# 25     True
# 26     True
# 27     True
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36     True
# 37    False
# 38    False
# 39    False
# 40    False
# 41     True
# 42     True
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48     True
# 49    False
# Name: harness_size, dtype: bool

# %%
#Apply mask to the data
data_from_small_dogs = dataset[is_small]
#data for dogs with small harness

print(data_from_small_dogs)

print(f"f\n Data of dogs with small harnesses{len(data_from_small_dogs)}")
# Out:
#     boot_size  harness_size
# 2          37            52
# 5          35            52
# 7          36            53
# 8          35            49
# 9          40            54
# 12         38            53
# 17         36            51
# 18         35            50
# 23         35            50
# 25         36            52
# 26         35            53
# 27         39            54
# 36         36            53
# 41         35            51
# 42         36            52
# 48         35            51
# f
#  Data of dogs with small harnesses16

# %%
#Compress the preocess ABOVE
data_small_paws = dataset[dataset.boot_size <40].copy()

print(f"We now have {len(data_small_paws)} rows in our dataset. The last few rows are:")
data_small_paws.tail()
# Out:
# We now have 34 rows in our dataset. The last few rows are:
#     boot_size  harness_size
# 42         36            52
# 46         39            58
# 47         39            57
# 48         35            51
# 49         39            59

# %%
import plotly.express
import graphing
plotly.express.scatter(data_small_paws, x ="harness_size", y="boot_size")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data_small_paws ['harness_size_imperial'] = data_small_paws.harness_size/2.54

plotly.express.scatter(data_small_paws, x = "harness_size_imperial", y = "boot_size")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#create a basic model 
#save it to disk
#load it from disk
#Use it to make prediction about a dog that was not in the training set

import pandas
# !wget https://raw.githubusercontent.com/MicrosoftDocs/mslearn-introduction-to-machine-learning/main/graphing.py
# !wget https://raw.githubusercontent.com/MicrosoftDocs/mslearn-introduction-to-machine-learning/main/Data/doggy-boot-harness.csv

#Load a file containing dog boot size and harnesses

data = pandas.read_csv('doggy-boot-harness.csv')

data.head()
# Out:
# --2022-07-15 12:26:34--  https://raw.githubusercontent.com/MicrosoftDocs/mslearn-introduction-to-machine-learning/main/graphing.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21511 (21K) [text/plain]
# Saving to: ‘graphing.py.1’
#
# graphing.py.1       100%[===================>]  21.01K  --.-KB/s    in 0.001s
#
# 2022-07-15 12:26:34 (25.8 MB/s) - ‘graphing.py.1’ saved [21511/21511]
#
# --2022-07-15 12:26:34--  https://raw.githubusercontent.com/MicrosoftDocs/mslearn-introduction-to-machine-learning/main/Data/doggy-boot-harness.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# ...

# %%
#Create and train the model
import statsmodels.formula.api as smf

model = smf.ols(formula = "boot_size ~ harness_size", data = data).fit()

print("Model Trained")
# Out:
# Model Trained

# %%
import joblib

model_filename = './avalanche_dog_boot_model.pkl'
joblib.dump(model, model_filename)

print("Model saved")
# Out:
# Model saved

# %%
#LOADING A MODEL

model_loaded = joblib.load(model_filename)
print("We have loaded a model with the following parameters")
print(model_loaded.params)
# Out:
# We have loaded a model with the following parameters
# Intercept       5.719110
# harness_size    0.585925
# dtype: float64

# %%
#PUTTING IT TOGETHER #cell did not run
def load_model_and_predict(harness_size):
  loaded_model = joblib.load(model_filename)
  print("We have loaded models with the following parameters:")
  print(loaded_model.params)

  inputs = {"harness size" :[harness_size]}
  predicted_boot_size = loaded_model.predict(inputs)[0]

  return predicted_boot_size

  predicted_boot_size = loaded_model_and_predict(45)

  print("Predicted dog boot size:", predicted_boot_size)
